# %%
### make predictions ###

# %%
from keras.models import load_model
import numpy as np
model = load_model('model.h5')

# %%
import cv2 as cv
import matplotlib.pyplot as plt 


im = cv.imread('/home/ricardo/Documents/AA/segmented/melanoma/SEGISIC_0000002.jpg',-1)
im_rgb = cv.cvtColor(im, cv.COLOR_BGR2RGB)
plt.imshow(im_rgb)

# %%
im_rgb.shape
x = np.expand_dims(im_rgb, axis=0)

# %%
x.shape
# Out:
# (1, 200, 200, 3)

# %%
model.predict(x)
# Out:
# 1/1 [==============================] - 0s 496ms/step
# array([[nan, nan, nan]], dtype=float32)
