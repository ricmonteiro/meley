# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torchvision
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.RandomHorizontalFlip(),
                                transforms.RandomVerticalFlip(),
                                transforms.RandomRotation(85),
                                transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

# %%
train_path = "/content/drive/MyDrive/AA_MEB/v3_Binary_keratosisVSmel_dataset/train/"
val_path = "/content/drive/MyDrive/AA_MEB/v3_Binary_keratosisVSmel_dataset/val/"
test_path = "/content/drive/MyDrive/AA_MEB/v3_Binary_keratosisVSmel_dataset/test/"

train_dataset = torchvision.datasets.ImageFolder(train_path, transform = transform)
val_dataset = torchvision.datasets.ImageFolder(val_path, transform = transform)
test_dataset = torchvision.datasets.ImageFolder(test_path, transform = transform)

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=16, shuffle=True, num_workers=2)

# %%
print("training set contains:", len(train_dataset), "images")
print("validation set contains:", len(val_dataset), "images")
print("testing set contains:", len(test_dataset), "images")
# Out:
# training set contains: 502 images
# validation set contains: 62 images
# testing set contains: 64 images

# %%
print(train_dataset.class_to_idx)
# Out:
# {'keratosis': 0, 'melanoma': 1}

# %%
images, labels = next(iter(train_loader))

images.shape # [batch_size, color_channels, height, width]
# Out:
# torch.Size([16, 3, 200, 200])

# %%
print("Number of images in training set: {}".format(len(train_dataset)))
print("Number of images in test set: {}".format(len(val_dataset)))
print("Number of images in test set: {}".format(len(test_dataset)))

print("...")

print("Number of batches in the train loader: {}".format(len(train_loader)))
print("Number of batches in the test loader: {}".format(len(val_loader)))
print("Number of batches in the test loader: {}".format(len(test_loader)))
# Out:
# Number of images in training set: 502
# Number of images in test set: 62
# Number of images in test set: 64
# ...
# Number of batches in the train loader: 32
# Number of batches in the test loader: 4
# Number of batches in the test loader: 4

# %%
CUDA = torch.cuda.is_available()

if CUDA:
  device = torch.device("cuda:0")
  print("GPU")
else:
  device = torch.device("cpu")
  print("CPU")
# Out:
# GPU

# %%
from torchvision import models

# %%
model = models.resnet50(pretrained=True)

for param in model.parameters():
  param.requires_grad = False

num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)

model = model.to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.fc.parameters(), lr=0.001)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def accuracy(predictions, labels):
    classes = torch.argmax(predictions, dim=1)
    return torch.mean((classes == labels).float())

# %%
import numpy as np

epochs = 50
min_valid_loss = np.inf

train_loss_values = []
valid_loss_values = []
train_acc = []
val_acc = []

for e in range(epochs):
    train_loss = []
    running_train_accuracy = 0.00

    model.train()     # Optional when not using Model Specific layer
    size = len(train_loader.dataset)
    for data, labels in train_loader:
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
            batch, c, h, w = data.shape 
        
        optimizer.zero_grad()
        predictions = model(data)
        t_loss = criterion(predictions,labels)
        t_loss.backward()
        optimizer.step()
        train_loss.append(t_loss.item())

        running_train_accuracy += accuracy(predictions, labels)

    running_train_accuracy /= len(train_loader)
    train_acc.append(running_train_accuracy.cpu())

    train_loss_values.append(np.array(train_loss).mean())

    valid_loss = []
    
    model.eval()     # Optional when not using Model Specific layer
    running_val_accuracy = 0.00
    for data, labels in val_loader:
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
        
        predictions = model(data)
        v_loss = criterion(predictions,labels)
        valid_loss.append(v_loss.item())
        running_val_accuracy += accuracy(predictions, labels)

    running_val_accuracy /= len(val_loader)

    valid_loss_values.append(np.array(valid_loss).mean())
    val_acc.append(running_val_accuracy.cpu())

    print(f'Epoch {e+1} \t\t Training Loss: {t_loss.item()} \t\t Validation Loss: {v_loss.item()}')
    print(f'Metrics \t\t Training accuracy: {running_train_accuracy} \t\t Validation accuracy: {running_val_accuracy}') 
        
        
    # Saving State Dict
    torch.save(model.state_dict(), '/content/drive/MyDrive/AA_MEB/v3_resnet50_model.pth')
# Out:
# Epoch 1 		 Training Loss: 0.6143007278442383 		 Validation Loss: 0.5558739304542542
# Metrics 		 Training accuracy: 0.5963541865348816 		 Validation accuracy: 0.6830357313156128
# Epoch 2 		 Training Loss: 0.7062558531761169 		 Validation Loss: 0.6344978213310242
# Metrics 		 Training accuracy: 0.6790364384651184 		 Validation accuracy: 0.6116071343421936
# Epoch 3 		 Training Loss: 0.591852605342865 		 Validation Loss: 0.4760798513889313
# Metrics 		 Training accuracy: 0.7102864384651184 		 Validation accuracy: 0.7142857313156128
# Epoch 4 		 Training Loss: 0.632834255695343 		 Validation Loss: 0.6422214508056641
# Metrics 		 Training accuracy: 0.7115885615348816 		 Validation accuracy: 0.7254464626312256
# Epoch 5 		 Training Loss: 0.5205462574958801 		 Validation Loss: 0.5184890031814575
# Metrics 		 Training accuracy: 0.7330729365348816 		 Validation accuracy: 0.7299107313156128
# Epoch 6 		 Training Loss: 0.5242193341255188 		 Validation Loss: 0.5003589987754822
# Metrics 		 Training accuracy: 0.7493489384651184 		 Validation accuracy: 0.7589285969734192
# Epoch 7 		 Training Loss: 0.7068904042243958 		 Validation Loss: 0.4638068974018097
# Metrics 		 Training accuracy: 0.728515625 		 Validation accuracy: 0.7633928656578064
# Epoch 8 		 Training Loss: 0.4882398843765259 		 Validation Loss: 0.5976927876472473
# Metrics 		 Training accuracy: 0.7506510615348816 		 Validation accuracy: 0.7589285969734192
# Epoch 9 		 Training Loss: 0.49002519249916077 		 Validation Loss: 0.4799328148365021
# Metrics 		 Training accuracy: 0.744140625 		 Validation accuracy: 0.8058035969734192
# Epoch 10 		 Training Loss: 0.40970027446746826 		 Validation Loss: 0.5703133344650269
# Metrics 		 Training accuracy: 0.765625 		 Validation accuracy: 0.7566964626312256
# Epoch 11 		 Training Loss: 0.43885770440101624 		 Validation Loss: 0.5584961771965027
# Metrics 		 Training accuracy: 0.7415364384651184 		 Validation accuracy: 0.7232142686843872
# Epoch 12 		 Training Loss: 0.47628310322761536 		 Validation Loss: 0.4338977038860321
# Metrics 		 Training accuracy: 0.7682291865348816 		 Validation accuracy: 0.7477678656578064
# Epoch 13 		 Training Loss: 0.34658434987068176 		 Validation Loss: 0.43458274006843567
# Metrics 		 Training accuracy: 0.75 		 Validation accuracy: 0.7120535969734192
# Epoch 14 		 Training Loss: 0.7248480916023254 		 Validation Loss: 0.5290524363517761
# Metrics 		 Training accuracy: 0.771484375 		 Validation accuracy: 0.6741071343421936
# Epoch 15 		 Training Loss: 0.5917051434516907 		 Validation Loss: 0.6387779116630554
# Metrics 		 Training accuracy: 0.7942708134651184 		 Validation accuracy: 0.7700892686843872
# Epoch 16 		 Training Loss: 0.5653600692749023 		 Validation Loss: 0.4863552451133728
# Metrics 		 Training accuracy: 0.7740885615348816 		 Validation accuracy: 0.6941964626312256
# Epoch 17 		 Training Loss: 0.5550640225410461 		 Validation Loss: 0.4824828505516052
# Metrics 		 Training accuracy: 0.7877604365348816 		 Validation accuracy: 0.7120535969734192
# Epoch 18 		 Training Loss: 0.3393823802471161 		 Validation Loss: 0.6084049940109253
# Metrics 		 Training accuracy: 0.783203125 		 Validation accuracy: 0.7544642686843872
# Epoch 19 		 Training Loss: 0.36324039101600647 		 Validation Loss: 0.47957780957221985
# Metrics 		 Training accuracy: 0.78125 		 Validation accuracy: 0.7589285969734192
# Epoch 20 		 Training Loss: 0.3043234646320343 		 Validation Loss: 0.5798234343528748
# Metrics 		 Training accuracy: 0.79296875 		 Validation accuracy: 0.8035714626312256
# Epoch 21 		 Training Loss: 0.3872341215610504 		 Validation Loss: 0.5610817074775696
# Metrics 		 Training accuracy: 0.798828125 		 Validation accuracy: 0.6741071343421936
# Epoch 22 		 Training Loss: 0.48644375801086426 		 Validation Loss: 0.4277525842189789
# Metrics 		 Training accuracy: 0.7884114384651184 		 Validation accuracy: 0.7767857313156128
# Epoch 23 		 Training Loss: 0.8158915638923645 		 Validation Loss: 0.4105532467365265
# Metrics 		 Training accuracy: 0.8125 		 Validation accuracy: 0.7433035969734192
# Epoch 24 		 Training Loss: 0.5555671453475952 		 Validation Loss: 0.4275433123111725
# Metrics 		 Training accuracy: 0.7766926884651184 		 Validation accuracy: 0.7924107313156128
# Epoch 25 		 Training Loss: 0.6448854804039001 		 Validation Loss: 0.45044612884521484
# Metrics 		 Training accuracy: 0.7513020634651184 		 Validation accuracy: 0.6651785969734192
# Epoch 26 		 Training Loss: 0.3392855226993561 		 Validation Loss: 0.5575085282325745
# Metrics 		 Training accuracy: 0.796875 		 Validation accuracy: 0.7142857313156128
# Epoch 27 		 Training Loss: 0.38103076815605164 		 Validation Loss: 0.5450376272201538
# Metrics 		 Training accuracy: 0.8170573115348816 		 Validation accuracy: 0.7611607313156128
# Epoch 28 		 Training Loss: 0.2557605803012848 		 Validation Loss: 0.6358252763748169
# Metrics 		 Training accuracy: 0.787109375 		 Validation accuracy: 0.7410714626312256
# Epoch 29 		 Training Loss: 0.4921906292438507 		 Validation Loss: 0.5909503102302551
# Metrics 		 Training accuracy: 0.7701823115348816 		 Validation accuracy: 0.6763392686843872
# Epoch 30 		 Training Loss: 0.6043931841850281 		 Validation Loss: 0.4587070941925049
# Metrics 		 Training accuracy: 0.7805989384651184 		 Validation accuracy: 0.8035714626312256
# Epoch 31 		 Training Loss: 0.4981323778629303 		 Validation Loss: 0.3849777281284332
# Metrics 		 Training accuracy: 0.7884114384651184 		 Validation accuracy: 0.7589285969734192
# Epoch 32 		 Training Loss: 0.44026780128479004 		 Validation Loss: 0.5479044318199158
# Metrics 		 Training accuracy: 0.8059895634651184 		 Validation accuracy: 0.8214285969734192
# Epoch 33 		 Training Loss: 0.6911492347717285 		 Validation Loss: 0.3784233629703522
# Metrics 		 Training accuracy: 0.8079426884651184 		 Validation accuracy: 0.7901785969734192
# Epoch 34 		 Training Loss: 0.49393323063850403 		 Validation Loss: 0.5126607418060303
# Metrics 		 Training accuracy: 0.76171875 		 Validation accuracy: 0.7566964626312256
# Epoch 35 		 Training Loss: 0.5112186074256897 		 Validation Loss: 0.36078110337257385
# Metrics 		 Training accuracy: 0.7903645634651184 		 Validation accuracy: 0.7299107313156128
# Epoch 36 		 Training Loss: 0.7084975242614746 		 Validation Loss: 0.506344735622406
# Metrics 		 Training accuracy: 0.8040364384651184 		 Validation accuracy: 0.7455357313156128
# Epoch 37 		 Training Loss: 0.8069413304328918 		 Validation Loss: 0.542995035648346
# Metrics 		 Training accuracy: 0.8059895634651184 		 Validation accuracy: 0.7410714626312256
# Epoch 38 		 Training Loss: 0.7073652148246765 		 Validation Loss: 0.6131249070167542
# Metrics 		 Training accuracy: 0.8177083134651184 		 Validation accuracy: 0.7075892686843872
# Epoch 39 		 Training Loss: 0.48620471358299255 		 Validation Loss: 0.5791791677474976
# Metrics 		 Training accuracy: 0.7669270634651184 		 Validation accuracy: 0.7410714626312256
# Epoch 40 		 Training Loss: 0.7630460262298584 		 Validation Loss: 0.36700358986854553
# Metrics 		 Training accuracy: 0.7923176884651184 		 Validation accuracy: 0.7433035969734192
# Epoch 41 		 Training Loss: 0.6186208128929138 		 Validation Loss: 0.4857221245765686
# Metrics 		 Training accuracy: 0.7955729365348816 		 Validation accuracy: 0.7745535969734192
# Epoch 42 		 Training Loss: 0.626120388507843 		 Validation Loss: 0.5713818669319153
# Metrics 		 Training accuracy: 0.8151041865348816 		 Validation accuracy: 0.7834821343421936
# Epoch 43 		 Training Loss: 0.36660441756248474 		 Validation Loss: 0.6984243392944336
# Metrics 		 Training accuracy: 0.7760416865348816 		 Validation accuracy: 0.7388392686843872
# Epoch 44 		 Training Loss: 0.6492692828178406 		 Validation Loss: 0.5865421295166016
# Metrics 		 Training accuracy: 0.775390625 		 Validation accuracy: 0.7410714626312256
# Epoch 45 		 Training Loss: 0.6593295931816101 		 Validation Loss: 0.5395706295967102
# Metrics 		 Training accuracy: 0.8001301884651184 		 Validation accuracy: 0.8035714626312256
# Epoch 46 		 Training Loss: 0.3275381326675415 		 Validation Loss: 0.33455905318260193
# Metrics 		 Training accuracy: 0.8033854365348816 		 Validation accuracy: 0.7790178656578064
# Epoch 47 		 Training Loss: 0.6955404877662659 		 Validation Loss: 0.6423100829124451
# Metrics 		 Training accuracy: 0.7903645634651184 		 Validation accuracy: 0.7232142686843872
# Epoch 48 		 Training Loss: 0.5381993651390076 		 Validation Loss: 0.5067434906959534
# Metrics 		 Training accuracy: 0.8072916865348816 		 Validation accuracy: 0.6964285969734192
# Epoch 49 		 Training Loss: 0.6683196425437927 		 Validation Loss: 0.5263177156448364
# Metrics 		 Training accuracy: 0.779296875 		 Validation accuracy: 0.7566964626312256
# Epoch 50 		 Training Loss: 0.8003170490264893 		 Validation Loss: 0.3831496238708496
# Metrics 		 Training accuracy: 0.79296875 		 Validation accuracy: 0.7455357313156128

# %%
plt.title("Loss over training")
plt.plot(train_loss_values)
plt.plot(valid_loss_values)
plt.legend(["train_loss", "valid_loss"])
plt.xlabel("epocs")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
plt.title("accuracy over training")
plt.plot(train_acc)
plt.plot(val_acc)
plt.legend(["train_acc", "valid_acc"])
plt.xlabel("epocs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.metrics import recall_score, accuracy_score, classification_report

# %%
y_pred = []
y_pred_prob = []
y_true = []

model = model.to(device)
model.load_state_dict(torch.load('/content/drive/MyDrive/AA_MEB/v3_resnet50_model.pth'))
model.eval()

# iterate over test data
for inputs, labels in test_loader:
        inputs, labels = inputs.cuda(), labels.cuda()
        output = model(inputs) # Feed Network

        output_pred = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output_pred)
        output_prob = torch.softmax(output.cpu(), dim=1)[:, 1].data.cpu().numpy()
        y_pred_prob.extend(output_prob) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        #labels = labels.cpu()
        y_true.extend(labels) # Save Truth

# %%
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.class_to_idx)
disp.plot()

# %%
cr = classification_report(y_true, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.71        26
#            1       0.82      0.74      0.78        38
#
#     accuracy                           0.75        64
#    macro avg       0.75      0.75      0.75        64
# weighted avg       0.76      0.75      0.75        64
