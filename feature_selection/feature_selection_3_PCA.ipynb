# %%
### APPLY PCA TO SELECTED FEATURES, IN HOPES TO REDUCE DIMENSIONALITY ###

# %%
# import modules
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load data with features and targets

fifty_neither_vs_mel_keratosis_feature_targets = pd.read_csv('fifty_neither_vs_mel_keratosis_feature_targets.csv')
mel_vs_keratosis_features_targets = pd.read_csv('mel_vs_keratosis_features_targets.csv')
neither_vs_melkeratosis_features_targets = pd.read_csv('neither_vs_melkeratosis_features_targets.csv')

# %%
fifty_neither_vs_mel_keratosis_feature_targets.head()
# Out:
#        image_id  red_mode  green_mode  blue_mode  red_iqr  green_iqr  \
# 0  ISIC_0000001        87          53         46       86         58
# 1  ISIC_0000002       162         120        114       26         52
# 2  ISIC_0000003       182         128         51       60         57
# 3  ISIC_0000004       192         132        171       36         44
# 4  ISIC_0000007       153         108         87       46         70
#
#    blue_iqr  original_firstorder_10Percentile  \
# 0        40                             112.0
# 1        67                             157.0
# 2        48                             176.0
# 3        55                              26.0
# 4        83                             134.0
#
#    original_firstorder_90Percentile  original_firstorder_Energy  ...  \
# 0                             135.0                  12760373.0  ...
# 1                             169.0                  43196758.0  ...
# ...
